# %% [markdown]
# ## Setup

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from fastai.vision.gan import *
from fastai.utils.mem import *
from fastai.callbacks import *

import os
import torchvision
from torchvision.utils import save_image

from torchvision.models import vgg16_bn

# %%
import DAT259.setup as setup
import DAT259.wgan as wgan
import DAT259.superresgan as superres
import DAT259.segmentation as seg

# %% [markdown]
# # Setup

# %% [markdown]
# ### Create a new project directory

# %%
project_name = 'test'
path_new_project = Path('Projects/' + project_name)

setup.create_folder(Path('Projects'))
setup.create_folder(path_new_project)

# %% [markdown]
# ### Create testset and available training data

# %%
path_mask = Path('data/ISIC2018_Task1_Training_GroundTruth')
path_img = Path('data/ISIC2018_Task1-2_Training_Input')

# %%
train, test = setup.split_train_test(path_img, path_mask, 100)

# %% [markdown]
# ### Save testset and available training data

# %%
path_data = Path(str(path_new_project) + '/data')
setup.create_folder(path_data)

# %%
train.to_csv(str(path_data) + '/available_training_data.csv')
test.to_csv(str(path_data) + '/test_data.csv')

# %% [markdown]
# # Generate masks

# %% [markdown]
# ### Directory for generated masks

# %%
path_gen = Path(str(path_new_project) + '/generator')
setup.create_folder(path_gen)

# %% [markdown]
# ### Get available training data

# %%
available_training_data = pd.read_csv(Path(str(path_data) + '/available_training_data.csv'), index_col = 0)
available_training_data.head()
# Out:
#               Image                           Mask
# 0  ISIC_0012517.jpg  ISIC_0012517_segmentation.png
# 1  ISIC_0016046.jpg  ISIC_0016046_segmentation.png
# 2  ISIC_0010382.jpg  ISIC_0010382_segmentation.png
# 3  ISIC_0000201.jpg  ISIC_0000201_segmentation.png
# 4  ISIC_0012950.jpg  ISIC_0012950_segmentation.png

# %% [markdown]
# ### Get trainingset with num_training_data masks

# %%
num_training_data = 100
training_data = available_training_data.sample(num_training_data)
print (len(training_data))
training_data.head()
# Out:
# 100
#                 Image                           Mask
# 35   ISIC_0011330.jpg  ISIC_0011330_segmentation.png
# 339  ISIC_0013748.jpg  ISIC_0013748_segmentation.png
# 91   ISIC_0015030.jpg  ISIC_0015030_segmentation.png
# 454  ISIC_0014164.jpg  ISIC_0014164_segmentation.png
# 185  ISIC_0011084.jpg  ISIC_0011084_segmentation.png

# %% [markdown]
# Save the dataframe with training data:

# %%
training_data.to_csv(str(path_data) + '/training_data_' + str(num_training_data) + '.csv')

# %% [markdown]
# ### Generate masks

# %% [markdown]
# Get the training data from file:

# %%
training_data = pd.read_csv(Path(str(path_data) + '/training_data_' + str(num_training_data) + '.csv'), index_col = 0)
training_data.head()
# Out:
#                 Image                           Mask
# 35   ISIC_0011330.jpg  ISIC_0011330_segmentation.png
# 339  ISIC_0013748.jpg  ISIC_0013748_segmentation.png
# 91   ISIC_0015030.jpg  ISIC_0015030_segmentation.png
# 454  ISIC_0014164.jpg  ISIC_0014164_segmentation.png
# 185  ISIC_0011084.jpg  ISIC_0011084_segmentation.png

# %% [markdown]
# Generate mask:

# %%
num_mask_to_gen = 100
path_gen_masks = Path(str(path_gen) + '/generated_masks_' + str(num_mask_to_gen))
wgan.generate_masks(training_data, num_mask_to_gen, path_mask, path_gen_masks, epochs=1, bs=50)
# Out:
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>gen_loss</th>
#       <th>disc_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>-0.031963</td>
#       <td>#na#</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>

# %%
wgan.image_cleaner(str(path_gen_masks))

# %% [markdown]
# ## Pretraining

# %%
training_data = pd.read_csv(Path(str(path_data) + '/training_data_' + str(num_training_data) + '.csv'), index_col = 0)

# %%
path_pretrained_masks = Path(str(path_gen) + '/pretrained_images_' + str(num_mask_to_gen))

learn = superres.train_generator(training_data, path_mask, path_img, path_pretrained_masks, num_epochs=1)
# Out:
# Total time: 00:27 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>pixel</th>
#       <th>feat_0</th>
#       <th>feat_1</th>
#       <th>feat_2</th>
#       <th>gram_0</th>
#       <th>gram_1</th>
#       <th>gram_2</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.525365</td>
#       <td>25.811930</td>
#       <td>12.044372</td>
#       <td>0.711886</td>
#       <td>0.776144</td>
#       <td>0.129621</td>
#       <td>7.273444</td>
#       <td>4.752049</td>
#       <td>0.124410</td>
#       <td>00:27</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 00:24 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>pixel</th>
#       <th>feat_0</th>
#       <th>feat_1</th>
#       <th>feat_2</th>
#       <th>gram_0</th>
#       <th>gram_1</th>
#       <th>gram_2</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>14.843451</td>
#       <td>4.535368</td>
#       <td>0.877490</td>
#       <td>0.329689</td>
#       <td>0.418548</td>
#       <td>0.125534</td>
#       <td>1.054403</td>
#       <td>1.599752</td>
#       <td>0.129952</td>
#       <td>00:24</td>
#     </tr>
#   </tbody>
# </table>

# %%
loss_critic = AdaptiveLoss(nn.BCEWithLogitsLoss())
superres.train_critic(100, Path('data'), path_gen, num_epochs=1)
# Out:
# Total time: 00:24 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh_expand</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.766783</td>
#       <td>0.535204</td>
#       <td>0.627857</td>
#       <td>00:24</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Train GAN

# %%
training_data = pd.read_csv(Path(str(path_data) + '/training_data_' + str(num_training_data) + '.csv'), index_col = 0)
training_data.head()
# Out:
#                 Image                           Mask
# 35   ISIC_0011330.jpg  ISIC_0011330_segmentation.png
# 339  ISIC_0013748.jpg  ISIC_0013748_segmentation.png
# 91   ISIC_0015030.jpg  ISIC_0015030_segmentation.png
# 454  ISIC_0014164.jpg  ISIC_0014164_segmentation.png
# 185  ISIC_0011084.jpg  ISIC_0011084_segmentation.png

# %%
learn_generator = superres.train_gan(training_data, path_mask, path_img, num_epochs=1)
# Out:
# Total time: 00:25 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>gen_loss</th>
#       <th>disc_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.709224</td>
#       <td>0.582383</td>
#       <td>00:25</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Generate images

# %%
path_gen_images = str(path_gen) + '/generated_images_' + str(num_mask_to_gen)
setup.create_folder(path_gen_images)

# %%
superres.pred_gan(learn_generator, path_gen_masks, path_gen_images, num_mask_to_gen)

# %% [markdown]
# # Segmentation

# %% [markdown]
# ### Resize testset

# %%
path_test = Path(str(path_new_project) + '/test')
setup.create_folder(path_test)

# %%
test_data = pd.read_csv(Path(str(path_data) + '/test_data.csv'), index_col = 0)

# %%
#images
img_size = 128
folder_name = 'test_img_' + str(img_size)
from_path = 'data/' + folder_name + '/'
to_path = Path(str(path_test) + '/' + folder_name)
test_img = test_data['Image']

seg.resize_img_folder(path_img, to_path, img_size, test_img)

# %%
#masks
img_size = 128
folder_name = 'test_mask_' + str(img_size)
from_path = 'data/' + folder_name + '/'
to_path = Path(str(path_test) + '/' + folder_name)
test_mask = test_data['Mask']

seg.resize_img_folder(path_mask, to_path, img_size, test_mask)

# %% [markdown]
# ### Experiment1

# %%
num_org_data = [100]
num_gen_data = [100, 0]

# %%
training_data = pd.read_csv(Path(str(path_data) + '/training_data_' + str(num_training_data) + '.csv'), index_col = 0)

# %%
setup.create_folder(str(path_new_project) + '/segmentation')
pred_path = Path(str(path_new_project) + '/segmentation/predictions')
setup.create_folder(pred_path)
setup.create_folder(str(path_new_project) + '/models')

model_path = Path (str(path_new_project) + '/models/segmentation_models') 
setup.create_folder(model_path)

# %%
the_list = [100]

for i in num_org_data:
    num_of_org_data = str(i)
    setup.create_folder(str(model_path) + '/' + str(i))
    setup.create_folder(str(pred_path) + '/' + str(i))
    # loop for segmentation using different amount of generated data 
    #from_ISIC = setup.get_data(Path('data/csv/csv_' + num_of_org_data))
    training_data = pd.read_csv(Path(str(path_data) + '/training_data_' + str(i) + '.csv'), index_col = 0)
    gen_img_folder = 'generated_images_'+ num_of_org_data
    gen_mask_folder = 'generated_masks_' + num_of_org_data
    #test_list = [100, 0]

    for j in num_gen_data:

        # creating dataframes for the orginal dataset and the generated data
        #number_of_generated_data = test_list[i]
        #print(path_gen_images)
        df = seg.merge_df(path_data, Path(str(path_gen) + '/' + gen_img_folder), Path(str(path_gen) + '/' + gen_mask_folder), training_data, j)
        #print(df)
        # creating data for model training
        data = seg.data_mix("", df)
        
        #create learner
        learner = seg.create_learner(data)

        #Training and saving the segmentation model
        model_name = 'seg_'+ str(i)+ '_' + str(j)
        #setup.create_folder(str(path_new_project) + 'models')
        #if (os.path.isdir('data/models/segmentation_models')==False): os.mkdir('data/models/segmentation_models')
        
        #if (os.path.isdir('data/models/segmentation_models/' + num_of_org_data)==False): os.mkdir('data/models/segmentation_models/' + num_of_org_data)
        #Se på dette!
        #if (os.path.isdir('data/predictions')==False): os.mkdir('data/predictions')
        #if (os.path.isdir('data/predictions/' + num_of_org_data)==False): os.mkdir('data/predictions/' + num_of_org_data)
        full_model_path = Path('../' + str(model_path) + '/' + str(i) + '/' + model_name)
        #print (full_model_path)
        #if (os.path.isdir(full_model_path)==False): os.mkdir(full_model_path)
        seg.seg_model(learner, full_model_path)
#gradient y=ax+b
        # prediction and saving them 
        save_pred_at = 'data/predictions/' + num_of_org_data + '/' + str(number_of_generated_data) + '/'
        if (os.path.isdir(save_pred_at)==False): os.mkdir(save_pred_at)
        seg.predict_on_test_data(learner, save_pred_at)
# Out:
# Total time: 00:12 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.390989</td>
#       <td>0.246047</td>
#       <td>0.503771</td>
#       <td>00:12</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 00:14 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.236617</td>
#       <td>0.225772</td>
#       <td>0.523052</td>
#       <td>00:14</td>
#     </tr>
#   </tbody>
# </table>
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-40-2ef045149ca7> in <module>
#      37         #print (full_model_path)
#      38         #if (os.path.isdir(full_model_path)==False): os.mkdir(full_model_path)
# ---> 39         seg.seg_model(learner, full_model_path)
#      40 #gradient y=ax+b
#      41         # prediction and saving them
#
# ~/Documents/Project_DAT259/Project_DAT259/DAT259/segmentation.py in seg_model(learn, model_name)
#     123     learn.fit_one_cycle(1, lrs, pct_start=0.8)
#     124
# --> 125     learn.save(model_name)
#     126
#     127
#
# ~/anaconda3/envs/fastai/lib/python3.7/site-packages/fastai/basic_train.py in save(self, name, return_path, with_opt)
#     249         if not with_opt: state = get_model(self.model).state_dict()
#     250         else: state = {'model': get_model(self.model).state_dict(), 'opt':self.opt.state_dict()}
# --> 251         torch.save(state, path)
#     252         if return_path: return path
#     253
#
# ~/anaconda3/envs/fastai/lib/python3.7/site-packages/torch/serialization.py in save(obj, f, pickle_module, pickle_protocol)
#     217         >>> torch.save(x, buffer)
#     218     """
# --> 219     return _with_file_like(f, "wb", lambda f: _save(obj, f, pickle_module, pickle_protocol))
#     220
#     221
#
# ~/anaconda3/envs/fastai/lib/python3.7/site-packages/torch/serialization.py in _with_file_like(f, mode, body)
#     140             (sys.version_info[0] == 3 and isinstance(f, pathlib.Path)):
#     141         new_fd = True
# --> 142         f = open(f, mode)
#     143     try:
#     144         return body(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'models/Projects/test/models/segmentation_models/100/seg_100_100.pth'

# %%
org = [100]
gen = [100, 0]
df10 = pd.DataFrame(columns = gen, index = org);
for i in org:
    for j in gen:
        df10[j][i] = seg.dice_score('data/predictions/'+ str(i)+ '/' + str(j), 'data/128x128/test_mask');

# %%
df10
# Out:
#           100      0
# 100  0.695312  0.66241

# %%
import datetime
date = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
if (os.path.isdir('data/results')==False): os.mkdir('data/results')
df10.to_csv('data/results/' + str(date))

# %%
df10.plot(kind='bar', figsize = (20,5), ylim=(0.5,0.9))
