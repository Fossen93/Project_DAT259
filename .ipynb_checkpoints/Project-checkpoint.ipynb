# %% [markdown]
# ## Setup

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from fastai.vision.gan import *
from fastai.utils.mem import *
from fastai.callbacks import *

import os
import torchvision
from torchvision.utils import save_image

from torchvision.models import vgg16_bn

# %%
import DAT259.setup as setup
import DAT259.wgan as wgan
import DAT259.superresgan as superres
import DAT259.segmentation as seg

# %% [markdown]
# # Setup

# %% [markdown]
# ### Create a new project directory

# %%
project_name = 'test'
path_new_project = Path('Projects/' + project_name)

setup.create_folder(Path('Projects'))
setup.create_folder(path_new_project)

# %% [markdown]
# ### Create testset and available training data

# %%
path_mask = Path('data/ISIC2018_Task1_Training_GroundTruth')
path_img = Path('data/ISIC2018_Task1-2_Training_Input')

# %%
train, test = setup.split_train_test(path_img, path_mask, 100)

# %% [markdown]
# ### Save testset and available training data

# %%
path_data = Path(str(path_new_project) + '/data')
setup.create_folder(path_data)
train.to_csv(str(path_data) + '/available_training_data.csv')
test.to_csv(str(path_data) + '/test_data.csv')

# %% [markdown]
# # Generate masks

# %% [markdown]
# ### Directory for generated masks

# %%
path_gen = Path(str(path_new_project) + '/generator')
setup.create_folder(path_gen)

# %% [markdown]
# ### Get available training data

# %%
available_training_data = pd.read_csv(Path(str(path_data) + '/available_training_data.csv'), index_col = 0)
available_training_data.head()
# Out:
#               Image                           Mask
# 0  ISIC_0016059.jpg  ISIC_0016059_segmentation.png
# 1  ISIC_0013167.jpg  ISIC_0013167_segmentation.png
# 2  ISIC_0000509.jpg  ISIC_0000509_segmentation.png
# 3  ISIC_0000359.jpg  ISIC_0000359_segmentation.png
# 4  ISIC_0013709.jpg  ISIC_0013709_segmentation.png

# %% [markdown]
# ### Get trainingset with num_training_data masks

# %%
num_training_data = 100
training_data = available_training_data.sample(num_training_data)
print (len(training_data))
training_data.head()
# Out:
# 100
#                 Image                           Mask
# 419  ISIC_0014263.jpg  ISIC_0014263_segmentation.png
# 13   ISIC_0012278.jpg  ISIC_0012278_segmentation.png
# 125  ISIC_0000067.jpg  ISIC_0000067_segmentation.png
# 17   ISIC_0012261.jpg  ISIC_0012261_segmentation.png
# 324  ISIC_0015476.jpg  ISIC_0015476_segmentation.png

# %% [markdown]
# Save the dataframe with training data:

# %%
training_data.to_csv(str(path_data) + '/training_data_' + str(num_training_data) + '.csv')

# %% [markdown]
# ### Generate masks

# %% [markdown]
# Get the training data from file:

# %%
training_data = pd.read_csv(Path(str(path_data) + '/training_data_' + str(num_training_data) + '.csv'), index_col = 0)
training_data.head()
# Out:
#                 Image                           Mask
# 419  ISIC_0014263.jpg  ISIC_0014263_segmentation.png
# 13   ISIC_0012278.jpg  ISIC_0012278_segmentation.png
# 125  ISIC_0000067.jpg  ISIC_0000067_segmentation.png
# 17   ISIC_0012261.jpg  ISIC_0012261_segmentation.png
# 324  ISIC_0015476.jpg  ISIC_0015476_segmentation.png

# %%
#training_data = training_data.reset_index()
#training_data = training_data.drop(['index'], axis=1)

# %% [markdown]
# Generate mask:

# %%
num_mask_to_gen = 100
path_gen_masks = Path(str(path_gen) + '/generated_masks_' + str(num_mask_to_gen))
wgan.generate_masks(training_data, num_mask_to_gen, path_mask, path_gen_masks, epochs=1, bs=50)
# Out:
# Total time: 00:12 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>gen_loss</th>
#       <th>disc_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>-0.085053</td>
#       <td>#na#</td>
#       <td>00:12</td>
#     </tr>
#   </tbody>
# </table>

# %%
wgan.image_cleaner(str(path_gen_masks))

# %% [markdown]
# ## Pretraining

# %%
training_data = pd.read_csv(Path(str(path_data) + '/training_data_' + str(num_training_data) + '.csv'), index_col = 0)

# %%
path_pretrained_masks = Path(str(path_gen) + '/pretrained_images_' + str(num_mask_to_gen))

learn = superres.train_generator(training_data, path_mask, path_img, path_pretrained_masks, num_epochs=1)
# Out:
# [autoreload of DAT259.superresgan failed: Traceback (most recent call last):
#   File "/home/sondre/anaconda3/envs/fastai/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/sondre/anaconda3/envs/fastai/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 378, in superreload
#     module = reload(module)
#   File "/home/sondre/anaconda3/envs/fastai/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/home/sondre/anaconda3/envs/fastai/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 724, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 860, in get_code
#   File "<frozen importlib._bootstrap_external>", line 791, in source_to_code
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home/sondre/Documents/Project_DAT259/Project_DAT259/DAT259/superresgan.py", line 126
#     file_names2 = pd.read_csv('Projects/test/generator/pretrained_mask'), index_col = 0)
#                                                                                        ^
# SyntaxError: invalid syntax
# ]
# [autoreload of DAT259.superresgan failed: Traceback (most recent call last):
#   File "/home/sondre/anaconda3/envs/fastai/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/sondre/anaconda3/envs/fastai/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 378, in superreload
#     module = reload(module)
#   File "/home/sondre/anaconda3/envs/fastai/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/home/sondre/anaconda3/envs/fastai/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 724, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 860, in get_code
#   File "<frozen importlib._bootstrap_external>", line 791, in source_to_code
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home/sondre/Documents/Project_DAT259/Project_DAT259/DAT259/superresgan.py", line 126
#     file_names2 = pd.read_csv('Projects/test/generator/pretrained_mask'), index_col = 0)
#                                                                                        ^
# SyntaxError: invalid syntax
# ]
# Total time: 00:29 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>pixel</th>
#       <th>feat_0</th>
#       <th>feat_1</th>
#       <th>feat_2</th>
#       <th>gram_0</th>
#       <th>gram_1</th>
#       <th>gram_2</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>5.233904</td>
#       <td>182.677246</td>
#       <td>37.359531</td>
#       <td>1.367607</td>
#       <td>3.113682</td>
#       <td>0.152788</td>
#       <td>32.323101</td>
#       <td>108.178627</td>
#       <td>0.181919</td>
#       <td>00:29</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 00:33 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>pixel</th>
#       <th>feat_0</th>
#       <th>feat_1</th>
#       <th>feat_2</th>
#       <th>gram_0</th>
#       <th>gram_1</th>
#       <th>gram_2</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>74.041748</td>
#       <td>4.190461</td>
#       <td>0.543395</td>
#       <td>0.325524</td>
#       <td>0.403920</td>
#       <td>0.102834</td>
#       <td>1.108406</td>
#       <td>1.609377</td>
#       <td>0.097005</td>
#       <td>00:33</td>
#     </tr>
#   </tbody>
# </table>

# %%
loss_critic = AdaptiveLoss(nn.BCEWithLogitsLoss())
superres.train_critic(100, num_epochs=1)
# Out:
#                                             Filenames  \
# 0            gen_l1_100/ISIC_0012741_segmentation.png
# 1            gen_l1_100/ISIC_0015952_segmentation.png
# 2            gen_l1_100/ISIC_0000102_segmentation.png
# 3            gen_l1_100/ISIC_0012278_segmentation.png
# 4            gen_l1_100/ISIC_0012324_segmentation.png
# 5            gen_l1_100/ISIC_0014394_segmentation.png
# 6            gen_l1_100/ISIC_0015476_segmentation.png
# 7            gen_l1_100/ISIC_0010588_segmentation.png
# 8            gen_l1_100/ISIC_0002469_segmentation.png
# 9            gen_l1_100/ISIC_0013794_segmentation.png
# 10           gen_l1_100/ISIC_0015631_segmentation.png
# 11           gen_l1_100/ISIC_0011143_segmentation.png
# 12           gen_l1_100/ISIC_0014574_segmentation.png
# 13           gen_l1_100/ISIC_0011169_segmentation.png
# 14           gen_l1_100/ISIC_0013606_segmentation.png
# 15           gen_l1_100/ISIC_0015109_segmentation.png
# 16           gen_l1_100/ISIC_0010247_segmentation.png
# 17           gen_l1_100/ISIC_0014890_segmentation.png
# 18           gen_l1_100/ISIC_0010240_segmentation.png
# 19           gen_l1_100/ISIC_0000124_segmentation.png
# 20           gen_l1_100/ISIC_0012681_segmentation.png
# 21           gen_l1_100/ISIC_0010347_segmentation.png
# 22           gen_l1_100/ISIC_0015102_segmentation.png
# 23           gen_l1_100/ISIC_0000409_segmentation.png
# 24           gen_l1_100/ISIC_0014308_segmentation.png
# 25           gen_l1_100/ISIC_0001960_segmentation.png
# 26           gen_l1_100/ISIC_0010380_segmentation.png
# 27           gen_l1_100/ISIC_0012662_segmentation.png
# 28           gen_l1_100/ISIC_0015157_segmentation.png
# 29           gen_l1_100/ISIC_0010041_segmentation.png
# ..                                                ...
# 150  ISIC2018_Task1-2_Training_Input/ISIC_0000007.jpg
# 151  ISIC2018_Task1-2_Training_Input/ISIC_0014162.jpg
# 152  ISIC2018_Task1-2_Training_Input/ISIC_0012204.jpg
# 153  ISIC2018_Task1-2_Training_Input/ISIC_0000157.jpg
# 154  ISIC2018_Task1-2_Training_Input/ISIC_0015958.jpg
# 155  ISIC2018_Task1-2_Training_Input/ISIC_0014833.jpg
# 156  ISIC2018_Task1-2_Training_Input/ISIC_0014166.jpg
# 157  ISIC2018_Task1-2_Training_Input/ISIC_0000444.jpg
# 158  ISIC2018_Task1-2_Training_Input/ISIC_0014609.jpg
# 159  ISIC2018_Task1-2_Training_Input/ISIC_0012330.jpg
# 160  ISIC2018_Task1-2_Training_Input/ISIC_0012261.jpg
# 161  ISIC2018_Task1-2_Training_Input/ISIC_0001105.jpg
# 162  ISIC2018_Task1-2_Training_Input/ISIC_0005548.jpg
# 163  ISIC2018_Task1-2_Training_Input/ISIC_0000147.jpg
# 164  ISIC2018_Task1-2_Training_Input/ISIC_0015464.jpg
# 165  ISIC2018_Task1-2_Training_Input/ISIC_0000233.jpg
# 166  ISIC2018_Task1-2_Training_Input/ISIC_0000447.jpg
# 167  ISIC2018_Task1-2_Training_Input/ISIC_0016055.jpg
# 168  ISIC2018_Task1-2_Training_Input/ISIC_0009973.jpg
# 169  ISIC2018_Task1-2_Training_Input/ISIC_0013371.jpg
# 170  ISIC2018_Task1-2_Training_Input/ISIC_0013369.jpg
# 171  ISIC2018_Task1-2_Training_Input/ISIC_0000098.jpg
# 172  ISIC2018_Task1-2_Training_Input/ISIC_0014974.jpg
# 173  ISIC2018_Task1-2_Training_Input/ISIC_0000523.jpg
# 174  ISIC2018_Task1-2_Training_Input/ISIC_0000234.jpg
# 175  ISIC2018_Task1-2_Training_Input/ISIC_0000067.jpg
# 176  ISIC2018_Task1-2_Training_Input/ISIC_0013023.jpg
# 177  ISIC2018_Task1-2_Training_Input/ISIC_0010094.jpg
# 178  ISIC2018_Task1-2_Training_Input/ISIC_0000120.jpg
# 179  ISIC2018_Task1-2_Training_Input/ISIC_0010241.jpg
#
#                                label
# 0                         gen_l1_100
# 1                         gen_l1_100
# 2                         gen_l1_100
# 3                         gen_l1_100
# 4                         gen_l1_100
# 5                         gen_l1_100
# 6                         gen_l1_100
# 7                         gen_l1_100
# 8                         gen_l1_100
# 9                         gen_l1_100
# 10                        gen_l1_100
# 11                        gen_l1_100
# 12                        gen_l1_100
# 13                        gen_l1_100
# 14                        gen_l1_100
# 15                        gen_l1_100
# 16                        gen_l1_100
# 17                        gen_l1_100
# 18                        gen_l1_100
# 19                        gen_l1_100
# 20                        gen_l1_100
# 21                        gen_l1_100
# 22                        gen_l1_100
# 23                        gen_l1_100
# 24                        gen_l1_100
# 25                        gen_l1_100
# 26                        gen_l1_100
# 27                        gen_l1_100
# 28                        gen_l1_100
# 29                        gen_l1_100
# ..                               ...
# 150  ISIC2018_Task1-2_Training_Input
# 151  ISIC2018_Task1-2_Training_Input
# 152  ISIC2018_Task1-2_Training_Input
# 153  ISIC2018_Task1-2_Training_Input
# 154  ISIC2018_Task1-2_Training_Input
# 155  ISIC2018_Task1-2_Training_Input
# 156  ISIC2018_Task1-2_Training_Input
# 157  ISIC2018_Task1-2_Training_Input
# 158  ISIC2018_Task1-2_Training_Input
# 159  ISIC2018_Task1-2_Training_Input
# 160  ISIC2018_Task1-2_Training_Input
# 161  ISIC2018_Task1-2_Training_Input
# 162  ISIC2018_Task1-2_Training_Input
# 163  ISIC2018_Task1-2_Training_Input
# 164  ISIC2018_Task1-2_Training_Input
# 165  ISIC2018_Task1-2_Training_Input
# 166  ISIC2018_Task1-2_Training_Input
# 167  ISIC2018_Task1-2_Training_Input
# 168  ISIC2018_Task1-2_Training_Input
# 169  ISIC2018_Task1-2_Training_Input
# 170  ISIC2018_Task1-2_Training_Input
# 171  ISIC2018_Task1-2_Training_Input
# 172  ISIC2018_Task1-2_Training_Input
# 173  ISIC2018_Task1-2_Training_Input
# 174  ISIC2018_Task1-2_Training_Input
# 175  ISIC2018_Task1-2_Training_Input
# 176  ISIC2018_Task1-2_Training_Input
# 177  ISIC2018_Task1-2_Training_Input
# 178  ISIC2018_Task1-2_Training_Input
# 179  ISIC2018_Task1-2_Training_Input
#
# [180 rows x 2 columns]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-30-0252346ab7a0> in <module>
#       1 loss_critic = AdaptiveLoss(nn.BCEWithLogitsLoss())
# ----> 2 superres.train_critic(100, num_epochs=1)
#
# ~/Documents/Project_DAT259/Project_DAT259/DAT259/superresgan.py in train_critic(num_data, num_epochs, wd)
#     129     labeled_data= label_data(file_names2, Path('data'), ['gen_l1_' + str(num_data), "ISIC2018_Task1-2_Training_Input"])
#     130     print(labeled_data)
# --> 131     data_crit = get_crit_data(labeled_data)
#     132     print(data_crit)
#     133     learn_critic = create_critic_learner(data_crit, accuracy_thresh_expand, wd)
#
# ~/Documents/Project_DAT259/Project_DAT259/DAT259/superresgan.py in get_crit_data(df, bs, size)
#     155     src = ImageList.from_df(path=Path('data'), df=df).split_by_rand_pct(0.1, seed=42)
#     156     ll = src.label_from_df('label')
# --> 157     data = (ll.transform(get_transforms(), size=size)
#     158            .databunch(bs=bs).normalize(imagenet_stats))
#     159     data.c = 3
#
# ~/anaconda3/envs/fastai/lib/python3.7/site-packages/fastai/data_block.py in transform(self, tfms, **kwargs)
#     488         if not tfms: tfms=(None,None)
#     489         assert is_listy(tfms) and len(tfms) == 2, "Please pass a list of two lists of transforms (train and valid)."
# --> 490         self.train.transform(tfms[0], **kwargs)
#     491         self.valid.transform(tfms[1], **kwargs)
#     492         if self.test: self.test.transform(tfms[1], **kwargs)
#
# ~/anaconda3/envs/fastai/lib/python3.7/site-packages/fastai/data_block.py in transform(self, tfms, tfm_y, **kwargs)
#     704     def transform(self, tfms:TfmList, tfm_y:bool=None, **kwargs):
#     705         "Set the `tfms` and `tfm_y` value to be applied to the inputs and targets."
# --> 706         _check_kwargs(self.x, tfms, **kwargs)
#     707         if tfm_y is None: tfm_y = self.tfm_y
#     708         if tfm_y: _check_kwargs(self.y, tfms, **kwargs)
#
# ~/anaconda3/envs/fastai/lib/python3.7/site-packages/fastai/data_block.py in _check_kwargs(ds, tfms, **kwargs)
#     575     if (tfms is None or len(tfms) == 0) and len(kwargs) == 0: return
#     576     if len(ds.items) >= 1:
# --> 577         x = ds[0]
#     578         try: x.apply_tfms(tfms, **kwargs)
#     579         except Exception as e:
#
# ~/anaconda3/envs/fastai/lib/python3.7/site-packages/fastai/data_block.py in __getitem__(self, idxs)
#     107     def __getitem__(self,idxs:int)->Any:
#     108         idxs = try_int(idxs)
# --> 109         if isinstance(idxs, Integral): return self.get(idxs)
#     110         else: return self.new(self.items[idxs], inner_df=index_row(self.inner_df, idxs))
#     111
#
# ~/anaconda3/envs/fastai/lib/python3.7/site-packages/fastai/vision/data.py in get(self, i)
#     269     def get(self, i):
#     270         fn = super().get(i)
# --> 271         res = self.open(fn)
#     272         self.sizes[i] = res.size
#     273         return res
#
# ~/anaconda3/envs/fastai/lib/python3.7/site-packages/fastai/vision/data.py in open(self, fn)
#     265     def open(self, fn):
#     266         "Open image in `fn`, subclass and overwrite for custom behavior."
# --> 267         return open_image(fn, convert_mode=self.convert_mode, after_open=self.after_open)
#     268
#     269     def get(self, i):
#
# ~/anaconda3/envs/fastai/lib/python3.7/site-packages/fastai/vision/image.py in open_image(fn, div, convert_mode, cls, after_open)
#     391     with warnings.catch_warnings():
#     392         warnings.simplefilter("ignore", UserWarning) # EXIF warning from TiffPlugin
# --> 393         x = PIL.Image.open(fn).convert(convert_mode)
#     394     if after_open: x = after_open(x)
#     395     x = pil2tensor(x,np.float32)
#
# ~/anaconda3/envs/fastai/lib/python3.7/site-packages/PIL/Image.py in open(fp, mode)
#    2632
#    2633     if filename:
# -> 2634         fp = builtins.open(filename, "rb")
#    2635         exclusive_fp = True
#    2636
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/gen_l1_100/ISIC_0012741_segmentation.png'

# %% [markdown]
# ## Train GAN

# %%
file_names = setup.get_data(Path('data/csv/csv_100'))

# %%
learn_generator = superres.train_gan(file_names, path_mask, path_img, num_epochs=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-5312b9b30496> in <module>
# ----> 1 learn_generator = superres.train_gan(file_names, path_mask, path_img, num_epochs=1)
#
# NameError: name 'file_names' is not defined

# %%
path_mask = Path('data/generated_mask_100')
path_gen = Path('data/generated_img_100')
superres.pred_gan(learn_generator, path_mask, path_gen, 100)

# %% [markdown]
# ## Segmentation

# %% [markdown]
# Preparing testset

# %%
#images
img_size = 128
folder_name = 'test_img'
from_path = 'data/' + folder_name + '/'
to_path = 'data/' + str(img_size) + 'x' + str(img_size) + '/' + folder_name + '/'

seg.resize_img_folder(from_path, to_path, img_size, folder_name)

# %%
#masks
img_size = 128
folder_name = 'test_mask'
from_path = 'data/' + folder_name + '/'
to_path = 'data/' + str(img_size) + 'x' + str(img_size) + '/' + folder_name + '/'

seg.resize_img_folder(from_path, to_path, img_size, folder_name)

# %% [markdown]
# ### Experiment1

# %%
the_list = [100]

for i in the_list:
    num_of_org_data = str(i)
    print(num_of_org_data)

    # loop for segmentation using different amount of generated data 
    from_ISIC = setup.get_data(Path('data/csv/csv_' + num_of_org_data))
    path = 'data/'
    gen_img_folder = 'generated_img_'+ num_of_org_data
    gen_mask_folder = 'generated_mask_' + num_of_org_data
    test_list = [100, 0]

    for i in range(len(test_list)):

        # creating dataframes for the orginal dataset and the generated data
        number_of_generated_data = test_list[i]
        df = seg.merge_df(path, gen_img_folder, gen_mask_folder, from_ISIC, number_of_generated_data)

        # creating data for model training
        data = seg.data_mix(path, df)

        #create learner
        learner = seg.create_learner(data)

        #Training and saving the segmentation model
        model_name = 'seg_'+ num_of_org_data+ '_' + str(number_of_generated_data)
        if (os.path.isdir('data/models/segmentation_models')==False): os.mkdir('data/models/segmentation_models')
        if (os.path.isdir('data/models/segmentation_models/' + num_of_org_data)==False): os.mkdir('data/models/segmentation_models/' + num_of_org_data)
        #Se på dette!
        if (os.path.isdir('data/predictions')==False): os.mkdir('data/predictions')
        if (os.path.isdir('data/predictions/' + num_of_org_data)==False): os.mkdir('data/predictions/' + num_of_org_data)
        full_model_path = 'segmentation_models/' + num_of_org_data + '/' + model_name
        #if (os.path.isdir(full_model_path)==False): os.mkdir(full_model_path)
        seg.seg_model(learner, full_model_path)
#gradient y=ax+b
        # prediction and saving them 
        save_pred_at = 'data/predictions/' + num_of_org_data + '/' + str(number_of_generated_data) + '/'
        if (os.path.isdir(save_pred_at)==False): os.mkdir(save_pred_at)
        seg.predict_on_test_data(learner, save_pred_at)
# Out:
# 100
# Total time: 00:13 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>dice</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.752431</td>
#       <td>0.174507</td>
#       <td>0.506460</td>
#       <td>0.595042</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 00:13 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>dice</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.186803</td>
#       <td>0.106366</td>
#       <td>0.505484</td>
#       <td>0.655032</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# 500
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# Total time: 00:13 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>dice</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.880973</td>
#       <td>0.378804</td>
#       <td>0.524118</td>
#       <td>0.297787</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>dice</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.412005</td>
#       <td>0.308526</td>
#       <td>0.481314</td>
#       <td>0.665552</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# 500
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei
# hei

# %%
org = [100]
gen = [100, 0]
df10 = pd.DataFrame(columns = gen, index = org);
for i in org:
    for j in gen:
        df10[j][i] = seg.dice_score('data/predictions/'+ str(i)+ '/' + str(j), 'data/128x128/test_mask');

# %%
df10
# Out:
#           100      0
# 100  0.695312  0.66241

# %%
import datetime
date = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
if (os.path.isdir('data/results')==False): os.mkdir('data/results')
df10.to_csv('data/results/' + str(date))

# %%
df10.plot(kind='bar', figsize = (20,5), ylim=(0.5,0.9))
